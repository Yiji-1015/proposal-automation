# %%
import os, requests

# %%
r = requests.post("http://192.168.123.33:5435/v1/embeddings", json={"model": os.getenv("EMBEDDING_MODEL_NAME", "BAAI/bge-m3"), "input": "테스트 문장"})

# %%
print(len(r.json()["data"][0]["embedding"]))
# Out:
# 1024
